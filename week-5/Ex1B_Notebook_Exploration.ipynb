# %%
print('hello world')
# Out:
# hello world

# %%
customer_id = 1002

customer_name = "Maria Lopez"

customer_gender = "Female"

customer_dob = "1982-09-23"

drivers_license = "L874602836"

auto_policy_number = "Auto-11223"

My_name = "Yanuris Campusano"
birth_city_state = "New York, New York"

# %%
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(name)
#
# NameError: name 'name' is not defined

# %%
print(customer_name)
print(my_name)
print(birth_city_state)
# Out:
# Maria Lopez
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 print(customer_name)
# ----> 2 print(my_name)
#       3 print(birth_city_state)
#
# NameError: name 'my_name' is not defined

# %%
print(customer_name)
print(My_name)
print(birth_city_state)
# Out:
# Maria Lopez
# Yanuris Campusano
# New York, New York
